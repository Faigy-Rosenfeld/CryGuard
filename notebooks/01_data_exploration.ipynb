# %% [markdown]
# # 01 - Data Exploration
# חקירת קבצי האודיו הגולמיים

# %%
import sys
sys.path.append('../src')
from audio_utils import load_audio, extract_melspectrogram
import matplotlib.pyplot as plt
import librosa.display
import os

DATA_DIR = '../data/raw'
