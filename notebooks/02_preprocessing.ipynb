# %% [markdown]
# # 02 - Preprocessing
# עיבוד מקדים ושמירת ספקטרוגרמות

# %%
import sys
sys.path.append('../src')
from audio_utils import load_audio, extract_melspectrogram
import numpy as np
import os

RAW_DIR = '../data/raw'
PROCESSED_DIR = '../data/processed'
